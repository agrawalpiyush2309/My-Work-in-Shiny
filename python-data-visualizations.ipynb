# %%
# %matplotlib notebook
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import math as math

# %%
a = pd.read_csv("iris.csv")

# %%
a.head()
# Out:
#    sepal.length  sepal.width  petal.length  petal.width variety
# 0           5.1          3.5           1.4          0.2  Setosa
# 1           4.9          3.0           1.4          0.2  Setosa
# 2           4.7          3.2           1.3          0.2  Setosa
# 3           4.6          3.1           1.5          0.2  Setosa
# 4           5.0          3.6           1.4          0.2  Setosa

# %%
# How many rows in each categories
a.groupby(["variety"],axis=0)["variety"].count()
# Out:
# variety
# Setosa        50
# Versicolor    50
# Virginica     50
# Name: variety, dtype: int64

# %%
fig,ax = plt.subplots(nrows = 1, ncols = 1)
ax.plot(a["sepal.length"],a["sepal.width"],'o')

xlabelrange = np.linspace(int(round(min(a["sepal.length"]))),int(math.ceil(max(a["sepal.length"]))),6)
ylabelrange = np.linspace(int(round(min(a["sepal.width"]))),int(math.ceil(max(a["sepal.width"]))),6)
ax.set_xticks(xlabelrange)
ax.set_yticks(ylabelrange)
ax.set_xlabel("sepal.length")
ax.set_ylabel("sepal.width")

plt.show()
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
#fig,ax = plt.subplots(nrows = 2, ncols = 2, figsize=(7, 7))
fig = plt.figure()

ax1 = plt.subplot2grid((3,3), (0,0), colspan=2)
ax2 = plt.subplot2grid((3,3), (1,0), colspan=2,rowspan=2)
ax3 = plt.subplot2grid((3,3), (1, 2), rowspan=2)


fig.subplots_adjust(wspace=0, hspace=0)

ax1.hist(a["sepal.length"],bins=10,facecolor='lightblue', alpha=0.75,edgecolor='black')
ax1.spines['right'].set_visible(False)
ax1.spines['left'].set_visible(False)
ax1.spines['top'].set_visible(False)
ax1.spines['bottom'].set_visible(False)
ax1.set_yticks([])
ax1.set_xticks([])


ax2.plot(a["sepal.length"],a["sepal.width"],'o',markersize=2)
ax2.xlabelrange = np.linspace(int(round(min(a["sepal.length"]))),int(math.ceil(max(a["sepal.length"]))),6)
ax2.ylabelrange = np.linspace(int(round(min(a["sepal.width"]))),int(math.ceil(max(a["sepal.width"]))),6)
ax2.spines['top'].set_visible(False)
ax2.set_xlabel("sepal.length")
ax2.set_ylabel("sepal.width")


ax3.hist(a["sepal.width"],bins=10,facecolor='lightblue', alpha=0.75,edgecolor='black',orientation='horizontal')
ax3.spines['right'].set_visible(False)
ax3.spines['left'].set_visible(False)
ax3.spines['top'].set_visible(False)
ax3.spines['bottom'].set_visible(False)
ax3.set_yticks([])
ax3.set_xticks([])

plt.show()
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
#fig,ax = plt.subplots(nrows = 2, ncols = 2, figsize=(7, 7))

values_dict = {'Setosa': 'r', 'Versicolor': 'b', 'Virginica': 'g'}

fig = plt.figure()

ax1 = plt.subplot2grid((3,3), (0,0), colspan=2)
ax2 = plt.subplot2grid((3,3), (1,0), colspan=2,rowspan=2)
ax3 = plt.subplot2grid((3,3), (1, 2), rowspan=2)


fig.subplots_adjust(wspace=0, hspace=0)

ax1.hist(a["sepal.length"],bins=10,facecolor='lightblue', alpha=0.75,edgecolor='black')
ax1.spines['right'].set_visible(False)
ax1.spines['left'].set_visible(False)
ax1.spines['top'].set_visible(False)
ax1.spines['bottom'].set_visible(False)
ax1.set_yticks([])
ax1.set_xticks([])

grouped = a.groupby('variety')
for key, group in grouped:
#    ax2.plot(ax=ax, kind='scatter', x='carat', y='price', label=key, color=colors[key])
  points =  ax2.plot(group["sepal.length"],group["sepal.width"],'o',markersize=2,color=values_dict[key])
    
    
#ax2.xlabelrange = np.linspace(int(round(min(a["sepal.length"]))),int(math.ceil(max(a["sepal.length"]))),6)
#ax2.ylabelrange = np.linspace(int(round(min(a["sepal.width"]))),int(math.ceil(max(a["sepal.width"]))),6)
ax2.spines['top'].set_visible(False)
ax2.set_xlabel("sepal.length")
ax2.set_ylabel("sepal.width")
ax2.legend(values_dict.keys())
ax2.set_xticks(np.linspace(int(round(min(a["sepal.length"]))),int(math.ceil(max(a["sepal.length"]))),5)/1.0)


ax3.hist(a["sepal.width"],bins=10,facecolor='lightblue', alpha=0.75,edgecolor='black',orientation='horizontal')
ax3.spines['right'].set_visible(False)
ax3.spines['left'].set_visible(False)
ax3.spines['top'].set_visible(False)
ax3.spines['bottom'].set_visible(False)
ax3.set_yticks([])
ax3.set_xticks([])

plt.show()
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
# varieties using boxplot
fig,ax = plt.subplots(nrows = 1, ncols = 1)

varieties = list(a["variety"].unique())
colors = ['red', 'blue', 'green']
i = 1
for variety,color in zip(varieties,colors):
    b = a[a["variety"] == variety].reset_index(drop = True)
    bp = ax.boxplot(b["petal.length"].values,positions = [i],patch_artist=True)
    bp['boxes'][0].set_facecolor(color)
    i+=1

ax.set_xlim(0.5, 3.5) 
ax.set_xticks(range(1,len(varieties)+1))
ax.set_xticklabels(varieties)

plt.show()
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
# varieties using boxplot
fig,ax = plt.subplots(nrows = 1, ncols = 1)

varieties = list(a["variety"].unique())
colors = ['red', 'blue', 'green']



i = 1
for variety,color in zip(varieties,colors):
    b = a[a["variety"] == variety].reset_index(drop = True)
    bp = ax.boxplot(b["petal.length"].values,positions = [i],patch_artist=True)
    x = np.random.normal(i, 0.1, len(b["petal.length"]))
    bp['boxes'][0].set_facecolor(color)
    points = ax.plot(b["petal.length"],x,color,marker='o')
    i+=2

ax.set_xlim(0.5, 7.5) 
ax.set_xticks(range(1,i))
ax.set_xticklabels(varieties)

plt.show()
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
#

values_dict = {'Setosa': 'r', 'Versicolor': 'b', 'Virginica': 'g'}

fig,ax = plt.subplots(nrows = 4, ncols = 4, figsize=(8, 8))

fig.subplots_adjust(wspace=0, hspace=0)

variables = 4
columns = list(a)[0:-2]

grouped = a.groupby('variety')

for columnrow,i in  zip(columns,range(0,variables)):
    for columncolumn,j in zip(columns,range(0,variables)):
        ax[i,j].spines['top'].set_visible(False)
        ax[i,j].spines['right'].set_visible(False)
        if (i==j):
            if(i!=0):
                ax[i,j].set_yticks([])
            for key,group in grouped:
                ax[i,j].hist(group[columnrow], 10, normed=1, histtype='bar', stacked=True,facecolor=values_dict[key], alpha=0.75,edgecolor='black')
        else:
            if(j>0):
                ax[i,j].set_yticks([])
                if(i!=variables-1): 
                    ax[i,j].set_yticks([])
            for key, group in grouped:
                points =  ax[i,j].plot(group[columnrow],group[columncolumn],'o',markersize=2,color=values_dict[key])
        if(j==0):
            ax[i,j].set_ylabel(columnrow)
        if(i==variables-1):
            ax[i,j].set_xlabel(columncolumn)
        
plt.show()
# Out:
# <img src="data:image/png;base64,..." width="800">

# %%
a.head()
# Out:
#    sepal.length  sepal.width  petal.length  petal.width variety color
# 0           5.1          3.5           1.4          0.2  Setosa     r
# 1           4.9          3.0           1.4          0.2  Setosa     r
# 2           4.7          3.2           1.3          0.2  Setosa     r
# 3           4.6          3.1           1.5          0.2  Setosa     r
# 4           5.0          3.6           1.4          0.2  Setosa     r

# %%
import numpy as np
import matplotlib.pyplot as plt

N = 5
men_means = (20, 35, 30, 35, 27)
men_std = (2, 3, 4, 1, 2)

ind = np.arange(N)  # the x locations for the groups
width = 0.35       # the width of the bars

fig, ax = plt.subplots()
rects1 = ax.bar(ind, men_means, width, color='r', yerr=men_std)

women_means = (25, 32, 34, 20, 25)
women_std = (3, 5, 2, 3, 3)
rects2 = ax.bar(ind + width, women_means, width, color='y', yerr=women_std)

# add some text for labels, title and axes ticks
ax.set_ylabel('Scores')
ax.set_title('Scores by group and gender')
ax.set_xticks(ind + width/ 2)
ax.set_xticklabels(('G1', 'G2', 'G3', 'G4', 'G5'))

ax.legend((rects1[0], rects2[0]), ('Men', 'Women'))


def autolabel(rects):
    """
    Attach a text label above each bar displaying its height
    """
    for rect in rects:
        height = rect.get_height()
        print("X is {}. Width is{}".format(rect.get_x(),rect.get_width()))
        ax.text(rect.get_x() + rect.get_width()/2., 1.05*height,
                '%d' % int(height),
                ha='center', va='bottom')

autolabel(rects1)
autolabel(rects2)

plt.show()
# Out:
# <img src="data:image/png;base64,..." width="640">
# X is -0.175. Width is0.35
# X is 0.825. Width is0.35
# X is 1.825. Width is0.35
# X is 2.825. Width is0.35
# X is 3.825. Width is0.35
# X is 0.175. Width is0.35
# X is 1.175. Width is0.35
# X is 2.1750000000000003. Width is0.35
# X is 3.1750000000000003. Width is0.35
# X is 4.175. Width is0.35
